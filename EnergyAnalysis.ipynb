# %%
import wbdata
import pandas

#wbdata.get_topic()
#wbdata.get_indicator(topic=5)
#wbdata.search_countries("united")

#wbdata.search_indicators("NY.GDP.PCAP.PP.KD")

indicators = {"NY.GDP.PCAP.PP.KD": "toto"}
df = wbdata.get_dataframe(indicators, country="USA")
df.info(verbose=True)
print(df.index)

df.plot()
#df.describe()
#df
#df.plot.hist(bins=100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58 entries, 2017 to 1960
# Data columns (total 1 columns):
# toto    28 non-null float64
# dtypes: float64(1)
# memory usage: 928.0+ bytes
# Index(['2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009',
#        '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000',
#        '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992', '1991',
#        '1990', '1989', '1988', '1987', '1986', '1985', '1984', '1983', '1982',
#        '1981', '1980', '1979', '1978', '1977', '1976', '1975', '1974', '1973',
#        '1972', '1971', '1970', '1969', '1968', '1967', '1966', '1965', '1964',
#        '1963', '1962', '1961', '1960'],
#       dtype='object', name='date')
